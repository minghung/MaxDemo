# %% [markdown]
# #Import packages

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("countries.csv")
df
# Out:
#           country continent  year  lifeExpectancy  population  gdpPerCapita
# 0     Afghanistan      Asia  1952          28.801     8425333    779.445314
# 1     Afghanistan      Asia  1957          30.332     9240934    820.853030
# 2     Afghanistan      Asia  1962          31.997    10267083    853.100710
# 3     Afghanistan      Asia  1967          34.020    11537966    836.197138
# 4     Afghanistan      Asia  1972          36.088    13079460    739.981106
# 5     Afghanistan      Asia  1977          38.438    14880372    786.113360
# 6     Afghanistan      Asia  1982          39.854    12881816    978.011439
# 7     Afghanistan      Asia  1987          40.822    13867957    852.395945
# 8     Afghanistan      Asia  1992          41.674    16317921    649.341395
# 9     Afghanistan      Asia  1997          41.763    22227415    635.341351
# 10    Afghanistan      Asia  2002          42.129    25268405    726.734055
# ...

# %%
df.head()
# Out:
#        country continent  year  lifeExpectancy  population  gdpPerCapita
# 0  Afghanistan      Asia  1952          28.801     8425333    779.445314
# 1  Afghanistan      Asia  1957          30.332     9240934    820.853030
# 2  Afghanistan      Asia  1962          31.997    10267083    853.100710
# 3  Afghanistan      Asia  1967          34.020    11537966    836.197138
# 4  Afghanistan      Asia  1972          36.088    13079460    739.981106

# %%
df.tail()
# Out:
#        country continent  year  lifeExpectancy  population  gdpPerCapita
# 1699  Zimbabwe    Africa  1987          62.351     9216418    706.157306
# 1700  Zimbabwe    Africa  1992          60.377    10704340    693.420786
# 1701  Zimbabwe    Africa  1997          46.809    11404948    792.449960
# 1702  Zimbabwe    Africa  2002          39.989    11926563    672.038623
# 1703  Zimbabwe    Africa  2007          43.487    12311143    469.709298

# %%
len(df.columns)*len(df)
# Out:
# 10224

# %%
df.size
# Out:
# 10224

# %%
df.shape
# Out:
# (1704, 6)

# %%
df["country"].unique()
# Out:
# array(['Afghanistan', 'Albania', 'Algeria', 'Angola', 'Argentina',
#        'Australia', 'Austria', 'Bahrain', 'Bangladesh', 'Belgium',
#        'Benin', 'Bolivia', 'Bosnia and Herzegovina', 'Botswana', 'Brazil',
#        'Bulgaria', 'Burkina Faso', 'Burundi', 'Cambodia', 'Cameroon',
#        'Canada', 'Central African Republic', 'Chad', 'Chile', 'China',
#        'Colombia', 'Comoros', 'Congo, Dem. Rep.', 'Congo, Rep.',
#        'Costa Rica', "Cote d'Ivoire", 'Croatia', 'Cuba', 'Czech Republic',
#        'Denmark', 'Djibouti', 'Dominican Republic', 'Ecuador', 'Egypt',
#        'El Salvador', 'Equatorial Guinea', 'Eritrea', 'Ethiopia',
#        'Finland', 'France', 'Gabon', 'Gambia', 'Germany', 'Ghana',
#        'Greece', 'Guatemala', 'Guinea', 'Guinea-Bissau', 'Haiti',
#        'Honduras', 'Hong Kong, China', 'Hungary', 'Iceland', 'India',
#        'Indonesia', 'Iran', 'Iraq', 'Ireland', 'Israel', 'Italy',
#        'Jamaica', 'Japan', 'Jordan', 'Kenya', 'Korea, Dem. Rep.',
# ...

# %%
df[df["country"]=="United States"]
# Out:
#             country continent  year  lifeExpectancy  population  gdpPerCapita
# 1608  United States  Americas  1952          68.440   157553000   13990.48208
# 1609  United States  Americas  1957          69.490   171984000   14847.12712
# 1610  United States  Americas  1962          70.210   186538000   16173.14586
# 1611  United States  Americas  1967          70.760   198712000   19530.36557
# 1612  United States  Americas  1972          71.340   209896000   21806.03594
# 1613  United States  Americas  1977          73.380   220239000   24072.63213
# 1614  United States  Americas  1982          74.650   232187835   25009.55914
# 1615  United States  Americas  1987          75.020   242803533   29884.35041
# 1616  United States  Americas  1992          76.090   256894189   32003.93224
# 1617  United States  Americas  1997          76.810   272911760   35767.43303
# 1618  United States  Americas  2002          77.310   287675526   39097.09955
# ...

# %%
df[(df["country"]=="United States") & (df["year"]==2007)]
# Out:
#             country continent  year  lifeExpectancy  population  gdpPerCapita
# 1619  United States  Americas  2007          78.242   301139947   42951.65309

# %%
df[(df["country"]=="United States") | (df["year"]==2007)]
# Out:
#                        country continent  year  lifeExpectancy  population  \
# 11                 Afghanistan      Asia  2007          43.828    31889923
# 23                     Albania    Europe  2007          76.423     3600523
# 35                     Algeria    Africa  2007          72.301    33333216
# 47                      Angola    Africa  2007          42.731    12420476
# 59                   Argentina  Americas  2007          75.320    40301927
# 71                   Australia   Oceania  2007          81.235    20434176
# 83                     Austria    Europe  2007          79.829     8199783
# 95                     Bahrain      Asia  2007          75.635      708573
# 107                 Bangladesh      Asia  2007          64.062   150448339
# 119                    Belgium    Europe  2007          79.441    10392226
# 131                      Benin    Africa  2007          56.728     8078314
# ...

# %%
df[["country","year","population"]]
# Out:
#           country  year  population
# 0     Afghanistan  1952     8425333
# 1     Afghanistan  1957     9240934
# 2     Afghanistan  1962    10267083
# 3     Afghanistan  1967    11537966
# 4     Afghanistan  1972    13079460
# 5     Afghanistan  1977    14880372
# 6     Afghanistan  1982    12881816
# 7     Afghanistan  1987    13867957
# 8     Afghanistan  1992    16317921
# 9     Afghanistan  1997    22227415
# 10    Afghanistan  2002    25268405
# 11    Afghanistan  2007    31889923
# 12        Albania  1952     1282697
# 13        Albania  1957     1476505
# 14        Albania  1962     1728137
# 15        Albania  1967     1984060
# 16        Albania  1972     2263554
# 17        Albania  1977     2509048
# 18        Albania  1982     2780097
# 19        Albania  1987     3075321
# 20        Albania  1992     3326498
# 21        Albania  1997     3428038
# 22        Albania  2002     3508512
# 23        Albania  2007     3600523
# 24        Algeria  1952     9279525
# ...

# %%
df.isnull().values.any()
# Out:
# False

# %%
df.dropna(inplace=True)

# %%
df.replace("?", np.nan, inplace=True)

# %%
df["continent"].value_counts()
# Out:
# Africa      624
# Asia        396
# Europe      360
# Americas    300
# Oceania      24
# Name: continent, dtype: int64

# %%
df[df["country"]=="United States"].describe()
# Out:
#               year  lifeExpectancy    population  gdpPerCapita
# count    12.000000       12.000000  1.200000e+01     12.000000
# mean   1979.500000       73.478500  2.282112e+08  26261.151347
# std      18.027756        3.343781  4.579019e+07   9695.058103
# min    1952.000000       68.440000  1.575530e+08  13990.482080
# 25%    1965.750000       70.622500  1.956685e+08  18691.060643
# 50%    1979.500000       74.015000  2.262134e+08  24541.095635
# 75%    1993.250000       76.270000  2.608986e+08  32944.807437
# max    2007.000000       78.242000  3.011399e+08  42951.653090

# %%
df[df["country"]=='Kuwait'].max()
# Out:
# country            Kuwait
# continent            Asia
# year                 2007
# lifeExpectancy     77.588
# population        2505559
# gdpPerCapita       113523
# dtype: object

# %%
df[df["country"]=='Kuwait']
# Out:
#     country continent  year  lifeExpectancy  population  gdpPerCapita
# 852  Kuwait      Asia  1952          55.565      160000  108382.35290
# 853  Kuwait      Asia  1957          58.033      212846  113523.13290
# 854  Kuwait      Asia  1962          60.470      358266   95458.11176
# 855  Kuwait      Asia  1967          64.624      575003   80894.88326
# 856  Kuwait      Asia  1972          67.712      841934  109347.86700
# 857  Kuwait      Asia  1977          69.343     1140357   59265.47714
# 858  Kuwait      Asia  1982          71.309     1497494   31354.03573
# 859  Kuwait      Asia  1987          74.174     1891487   28118.42998
# 860  Kuwait      Asia  1992          75.190     1418095   34932.91959
# 861  Kuwait      Asia  1997          76.156     1765345   40300.61996
# 862  Kuwait      Asia  2002          76.904     2111561   35110.10566
# 863  Kuwait      Asia  2007          77.588     2505559   47306.98978

# %%
df.dtypes
# Out:
# country            object
# continent          object
# year                int64
# lifeExpectancy    float64
# population          int64
# gdpPerCapita      float64
# dtype: object

# %%
df["gdp"] = df["population"] * df["gdpPerCapita"]
df.head()
# Out:
#        country continent  year  lifeExpectancy  population  gdpPerCapita  \
# 0  Afghanistan      Asia  1952          28.801     8425333    779.445314
# 1  Afghanistan      Asia  1957          30.332     9240934    820.853030
# 2  Afghanistan      Asia  1962          31.997    10267083    853.100710
# 3  Afghanistan      Asia  1967          34.020    11537966    836.197138
# 4  Afghanistan      Asia  1972          36.088    13079460    739.981106
#
#             gdp
# 0  6.567086e+09
# 1  7.585449e+09
# 2  8.758856e+09
# 3  9.648014e+09
# 4  9.678553e+09

# %%
df.drop(["gdp"], axis=1)
# Out:
#           country continent  year  lifeExpectancy  population  gdpPerCapita
# 0     Afghanistan      Asia  1952          28.801     8425333    779.445314
# 1     Afghanistan      Asia  1957          30.332     9240934    820.853030
# 2     Afghanistan      Asia  1962          31.997    10267083    853.100710
# 3     Afghanistan      Asia  1967          34.020    11537966    836.197138
# 4     Afghanistan      Asia  1972          36.088    13079460    739.981106
# 5     Afghanistan      Asia  1977          38.438    14880372    786.113360
# 6     Afghanistan      Asia  1982          39.854    12881816    978.011439
# 7     Afghanistan      Asia  1987          40.822    13867957    852.395945
# 8     Afghanistan      Asia  1992          41.674    16317921    649.341395
# 9     Afghanistan      Asia  1997          41.763    22227415    635.341351
# 10    Afghanistan      Asia  2002          42.129    25268405    726.734055
# ...

# %%
del df["gdp"]

# %%
df
# Out:
#           country continent  year  lifeExpectancy  population  gdpPerCapita
# 0     Afghanistan      Asia  1952          28.801     8425333    779.445314
# 1     Afghanistan      Asia  1957          30.332     9240934    820.853030
# 2     Afghanistan      Asia  1962          31.997    10267083    853.100710
# 3     Afghanistan      Asia  1967          34.020    11537966    836.197138
# 4     Afghanistan      Asia  1972          36.088    13079460    739.981106
# 5     Afghanistan      Asia  1977          38.438    14880372    786.113360
# 6     Afghanistan      Asia  1982          39.854    12881816    978.011439
# 7     Afghanistan      Asia  1987          40.822    13867957    852.395945
# 8     Afghanistan      Asia  1992          41.674    16317921    649.341395
# 9     Afghanistan      Asia  1997          41.763    22227415    635.341351
# 10    Afghanistan      Asia  2002          42.129    25268405    726.734055
# ...

# %%
df.iloc[5]["population"]
# Out:
# 14880372

# %%
df["population"]
# Out:
# 0        8425333
# 1        9240934
# 2       10267083
# 3       11537966
# 4       13079460
# 5       14880372
# 6       12881816
# 7       13867957
# 8       16317921
# 9       22227415
# 10      25268405
# 11      31889923
# 12       1282697
# 13       1476505
# 14       1728137
# 15       1984060
# 16       2263554
# 17       2509048
# 18       2780097
# 19       3075321
# 20       3326498
# 21       3428038
# 22       3508512
# 23       3600523
# 24       9279525
# 25      10270856
# 26      11000948
# 27      12760499
# 28      14760787
# 29      17152804
#           ...
# 1674     9657618
# 1675    11219340
# 1676    13367997
# 1677    15826497
# 1678    18701257
# 1679    22211743
# 1680     2672000
# 1681     3016000
# 1682     3421000
# 1683     3900000
# 1684     4506497
# 1685     5216550
# 1686     6100407
# 1687     7272406
# 1688     8381163
# 1689     9417789
# 1690    10595811
# 1691    11746035
# 1692     3080907
# 1693     3646340
# 1694     4277736
# ...

# %%
df[df["country"]=="United States"].sort_values("population", ascending=False)
# Out:
#             country continent  year  lifeExpectancy  population  gdpPerCapita
# 1619  United States  Americas  2007          78.242   301139947   42951.65309
# 1618  United States  Americas  2002          77.310   287675526   39097.09955
# 1617  United States  Americas  1997          76.810   272911760   35767.43303
# 1616  United States  Americas  1992          76.090   256894189   32003.93224
# 1615  United States  Americas  1987          75.020   242803533   29884.35041
# 1614  United States  Americas  1982          74.650   232187835   25009.55914
# 1613  United States  Americas  1977          73.380   220239000   24072.63213
# 1612  United States  Americas  1972          71.340   209896000   21806.03594
# 1611  United States  Americas  1967          70.760   198712000   19530.36557
# 1610  United States  Americas  1962          70.210   186538000   16173.14586
# 1609  United States  Americas  1957          69.490   171984000   14847.12712
# ...

# %%
df.groupby("country")

# %%
df_usa = df[df["country"]=="United States"]
df_china = df[df["country"]=="China"]
plt.plot(df_usa["year"], df_usa["population"]/df_usa.iloc[0]["population"]*100)
plt.plot(df_china["year"], df_china["population"]/df_china.iloc[0]["population"]*100)
plt.legend(["USA", "China"])
plt.ylabel("Population % change")
plt.xlabel("Year")
plt.show()

# %%
df_india = df[df["country"]=="China"]
df_india = df[df["country"]=="India"]

plt.subplot(2,1,1)
plt.plot(df_china["gdpPerCapita"], df_china["population"]/10**6)
plt.ylabel("Population in M")

plt.subplot(2,1,2)
plt.plot(df_india["gdpPerCapita"], df_india["population"]/10**6)
plt.xlabel("GDP per Capita")
plt.ylabel("Population in M")

plt.show()

# %%
plt.scatter(df["gdpPerCapita"], df["lifeExpectancy"])
plt.xlabel("GDP per Capita")
plt.ylabel("Life Expectance")
plt.show()

# %%
df_2007 = df[df["year"]==2007]
plt.scatter(df_2007["gdpPerCapita"], df_2007["lifeExpectancy"])
plt.xlabel("GDP per Capita")
plt.ylabel("Life Expectance")
plt.show()

# %%
df[(df["year"]==2007) & (df["gdpPerCapita"]<5000)].sort_values("lifeExpectancy", ascending=False).head(10)
# Out:
#                  country continent  year  lifeExpectancy  population  \
# 1655             Vietnam      Asia  2007          74.249    85262356
# 1499               Syria      Asia  2007          74.143    19314747
# 1667  West Bank and Gaza      Asia  2007          73.422     4018332
# 299                China      Asia  2007          72.961  1318683096
# 1115           Nicaragua  Americas  2007          72.899     5675356
# 815               Jordan      Asia  2007          72.535     6053193
# 1439           Sri Lanka      Asia  2007          72.396    20378239
# 1199            Paraguay  Americas  2007          71.752     6667147
# 1223         Philippines      Asia  2007          71.688    91077287
# 1031             Morocco    Africa  2007          71.164    33757175
#
#       gdpPerCapita
# 1655   2441.576404
# 1499   4184.548089
# 1667   3025.349798
# 299    4959.114854
# 1115   2749.320965
# 815    4519.461171
# 1439   3970.095407
# 1199   4172.838464
# 1223   3190.481016
# ...

# %%
df["gdpPerCapita"].corr(df["lifeExpectancy"]
# Out:
# 0.5837062198659806

# %%
df_2007["gdpPerCapita"].corr(df_2007["lifeExpectancy"])
# Out:
# 0.6786623986777587

# %%
plt.scatter(df_2007["logGdpPerCapita"], df_2007["lifeExpectancy"])
plt.xlabel("GDP per Capita")
plt.ylabel("Life Expectance")
plt.show()

# %%
df_2007["logGdpPerCapita"] = np.log10(df_2007["gdpPerCapita"])
# Out:
# C:\Users\Ming\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
df_2007
# Out:
#                        country continent  year  lifeExpectancy  population  \
# 11                 Afghanistan      Asia  2007          43.828    31889923
# 23                     Albania    Europe  2007          76.423     3600523
# 35                     Algeria    Africa  2007          72.301    33333216
# 47                      Angola    Africa  2007          42.731    12420476
# 59                   Argentina  Americas  2007          75.320    40301927
# 71                   Australia   Oceania  2007          81.235    20434176
# 83                     Austria    Europe  2007          79.829     8199783
# 95                     Bahrain      Asia  2007          75.635      708573
# 107                 Bangladesh      Asia  2007          64.062   150448339
# 119                    Belgium    Europe  2007          79.441    10392226
# 131                      Benin    Africa  2007          56.728     8078314
# ...

# %%
df_2007.dtypes
# Out:
# country            object
# continent          object
# year                int64
# lifeExpectancy    float64
# population          int64
# gdpPerCapita      float64
# s1                float64
# dtype: object

# %%
df_2007["logGdpPerCapita"].corr(df_2007["lifeExpectancy"])
# Out:
# 0.8089802514849209

# %%
df_2007["s2"] = np.log(df_2007["gdpPerCapita"])
# Out:
# C:\Users\Ming\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
df_2007
# Out:
#                        country continent  year  lifeExpectancy  population  \
# 11                 Afghanistan      Asia  2007          43.828    31889923
# 23                     Albania    Europe  2007          76.423     3600523
# 35                     Algeria    Africa  2007          72.301    33333216
# 47                      Angola    Africa  2007          42.731    12420476
# 59                   Argentina  Americas  2007          75.320    40301927
# 71                   Australia   Oceania  2007          81.235    20434176
# 83                     Austria    Europe  2007          79.829     8199783
# 95                     Bahrain      Asia  2007          75.635      708573
# 107                 Bangladesh      Asia  2007          64.062   150448339
# 119                    Belgium    Europe  2007          79.441    10392226
# 131                      Benin    Africa  2007          56.728     8078314
# ...

# %%
df_2007["s1"].corr(df_2007["lifeExpectancy"])
# Out:
# 0.8089802514849209

# %%
df_sample = pd.DataFrame([["Red", 1], ["Blue", 0], ["Green", 4], ["Blue", 3], ["Red", 7]], columns=["Color","Qtr"])

# %%
df_sample
# Out:
#    Color  Qtr
# 0    Red    1
# 1   Blue    0
# 2  Green    4
# 3   Blue    3
# 4    Red    7

# %%
pd.get_dummies(df_sample, columns=["Color"])
# Out:
#    Qtr  Color_Blue  Color_Green  Color_Red
# 0    1           0            0          1
# 1    0           1            0          0
# 2    4           0            1          0
# 3    3           1            0          0
# 4    7           0            0          1

# %%
from sklearn import preprocessing
le = preprocessing.LabelEncoder()
df["country"]=le.fit_transform(df["country"].astype(str))

# %%
le.classes_
# Out:
# array(['Afghanistan', 'Albania', 'Algeria', 'Angola', 'Argentina',
#        'Australia', 'Austria', 'Bahrain', 'Bangladesh', 'Belgium',
#        'Benin', 'Bolivia', 'Bosnia and Herzegovina', 'Botswana', 'Brazil',
#        'Bulgaria', 'Burkina Faso', 'Burundi', 'Cambodia', 'Cameroon',
#        'Canada', 'Central African Republic', 'Chad', 'Chile', 'China',
#        'Colombia', 'Comoros', 'Congo, Dem. Rep.', 'Congo, Rep.',
#        'Costa Rica', "Cote d'Ivoire", 'Croatia', 'Cuba', 'Czech Republic',
#        'Denmark', 'Djibouti', 'Dominican Republic', 'Ecuador', 'Egypt',
#        'El Salvador', 'Equatorial Guinea', 'Eritrea', 'Ethiopia',
#        'Finland', 'France', 'Gabon', 'Gambia', 'Germany', 'Ghana',
#        'Greece', 'Guatemala', 'Guinea', 'Guinea-Bissau', 'Haiti',
#        'Honduras', 'Hong Kong, China', 'Hungary', 'Iceland', 'India',
#        'Indonesia', 'Iran', 'Iraq', 'Ireland', 'Israel', 'Italy',
#        'Jamaica', 'Japan', 'Jordan', 'Kenya', 'Korea, Dem. Rep.',
# ...

# %%
df.head()
# Out:
#    country continent  year  lifeExpectancy  population  gdpPerCapita
# 0        0      Asia  1952          28.801     8425333    779.445314
# 1        0      Asia  1957          30.332     9240934    820.853030
# 2        0      Asia  1962          31.997    10267083    853.100710
# 3        0      Asia  1967          34.020    11537966    836.197138
# 4        0      Asia  1972          36.088    13079460    739.981106

# %%
df = pd.get_dummies(df, columns=["continent"])

# %%
y_test
# Out:
# 249     78.610
# 6       39.854
# 217     41.366
# 966     53.599
# 1674    49.113
# 161     59.319
# 1344    30.331
# 686     73.680
# 632     43.266
# 262     43.308
# 1494    64.590
# 918     48.969
# 393     76.151
# 1234    74.670
# 1535    70.616
# 575     79.406
# 1640    71.150
# 182     69.510
# 1642    72.766
# 425     46.519
# 1063    60.835
# 616     38.842
# 1632    55.088
# 251     80.653
# 481     35.983
# 905     57.442
# 353     70.750
# 1613    73.380
# 148     67.450
# 34      70.994
#          ...
# 517     67.490
# 308     68.421
# 434     53.459
# 1147    75.890
# 536     77.460
# 1014    74.101
# 1391    77.926
# 1132    42.821
# 1672    39.848
# 1279    69.530
# 1305    63.306
# 1562    49.579
# 1248    64.280
# 133     41.890
# 202     50.650
# 1319    72.777
# 506     40.059
# 1157    57.367
# 482     37.485
# 501     53.378
# 317     50.939
# 142     63.883
# 771     71.060
# 1074    49.594
# 776     77.440
# 1058    48.386
# 315     46.472
# ...

# %%
from sklearn.model_selection import train_test_split
x = df.drop("lifeExpectancy", axis=1)
y = df["lifeExpectancy"]
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=0)

# %%
from sklearn.linear_model import LinearRegression
lm = LinearRegression()
lm.fit(x_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
lm.score(x_train, y_train)
# Out:
# 0.7187549050111581

# %%
lm.coef_
# Out:
# array([ 1.91991539e-02,  2.89606545e-01,  1.06038178e-09,  2.72264033e-04,
#        -1.33404472e+01,  1.58682004e+00, -3.35892638e+00,  6.68018443e+00,
#         8.43236909e+00])

# %%
pd.Series(lm.coef_, x_train.columns).sort_values()
# Out:
# continent_Africa     -1.334045e+01
# continent_Asia       -3.358926e+00
# population            1.060382e-09
# gdpPerCapita          2.722640e-04
# country               1.919915e-02
# year                  2.896065e-01
# continent_Americas    1.586820e+00
# continent_Europe      6.680184e+00
# continent_Oceania     8.432369e+00
# dtype: float64

# %%
y_predict = lm.predict(x_test)

# %%
plt.plot(y_predict, label="Predicted")
plt.plot(y_test.values, label="Actual")
plt.ylabel("Life Expectancy")
plt.legend()
plt.show()

# %%
lm.score(x_test, y_test)
# Out:
# 0.7310283226101895
