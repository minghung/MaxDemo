# %%
import pandas as pd

# %%
df = pd.read_csv("NYPD_7_Major_Felony_Incidents.zip", compression="zip")

# %%
len(df)
# Out:
# 1123465

# %%
df.size
# Out:
# 22469300

# %%
df.columns
# Out:
# Index(['OBJECTID', 'Identifier', 'Occurrence Date', 'Day of Week',
#        'Occurrence Month', 'Occurrence Day', 'Occurrence Year',
#        'Occurrence Hour', 'CompStat Month', 'CompStat Day', 'CompStat Year',
#        'Offense', 'Offense Classification', 'Sector', 'Precinct', 'Borough',
#        'Jurisdiction', 'XCoordinate', 'YCoordinate', 'Location 1'],
#       dtype='object')

# %%
len(df.columns)
# Out:
# 20

# %%
len(df) * len(df.columns)
# Out:
# 22469300

# %%
df.shape
# Out:
# (1123465, 20)

# %%
df.head(10)
# Out:
#    OBJECTID Identifier         Occurrence Date Day of Week Occurrence Month  \
# 0       1.0   f070032d  09/06/1940 07:30:00 PM      Friday              Sep
# 1       2.0   c6245d4d  12/14/1968 12:20:00 AM    Saturday              Dec
# 2       3.0   716dbc6f  10/30/1970 03:30:00 PM      Friday              Oct
# 3       4.0   638cd7b7  07/18/1972 11:00:00 PM     Tuesday              Jul
# 4       5.0   6e410287  05/21/1987 12:01:00 AM    Thursday              May
# 5       6.0   7eebfe3c  02/01/1990 09:00:00 AM    Thursday              Feb
# 6       7.0   da21f94f  11/13/1990 12:01:00 AM     Tuesday              Nov
# 7       8.0   87c99e8c  02/02/1992 04:00:00 PM      Sunday              Feb
# 8       9.0   495f57e1  08/08/1994 06:00:00 PM      Monday              Aug
# 9      10.0   31c0b727  10/26/1994 12:01:00 AM   Wednesday              Oct
#
#    Occurrence Day  Occurrence Year  Occurrence Hour  CompStat Month  \
# ...

# %%
df.count()
# Out:
# OBJECTID                  1123464
# Identifier                1123465
# Occurrence Date           1123222
# Day of Week               1123291
# Occurrence Month          1123291
# Occurrence Day            1123291
# Occurrence Year           1123221
# Occurrence Hour           1123222
# CompStat Month            1123463
# CompStat Day              1123463
# CompStat Year             1123463
# Offense                   1123464
# Offense Classification    1123464
# Sector                    1098137
# Precinct                  1123443
# Borough                   1123384
# Jurisdiction              1123463
# XCoordinate               1123464
# YCoordinate               1123464
# Location 1                1123464
# dtype: int64

# %%
df["Day of Week"].isnull()
# Out:
# 0          False
# 1          False
# 2          False
# 3          False
# 4          False
# 5          False
# 6          False
# 7          False
# 8          False
# 9          False
# 10         False
# 11         False
# 12         False
# 13         False
# 14         False
# 15         False
# 16         False
# 17         False
# 18         False
# 19         False
# 20         False
# 21         False
# 22         False
# 23         False
# 24         False
# 25         False
# 26         False
# 27         False
# 28         False
# 29         False
#            ...
# 1123435    False
# 1123436    False
# 1123437    False
# 1123438    False
# 1123439    False
# 1123440    False
# 1123441    False
# 1123442    False
# 1123443    False
# 1123444    False
# 1123445    False
# 1123446    False
# 1123447    False
# 1123448    False
# 1123449    False
# 1123450    False
# 1123451    False
# 1123452    False
# 1123453    False
# 1123454    False
# 1123455    False
# ...

# %%
df["Day of Week"]
# Out:
# 0             Friday
# 1           Saturday
# 2             Friday
# 3            Tuesday
# 4           Thursday
# 5           Thursday
# 6            Tuesday
# 7             Sunday
# 8             Monday
# 9          Wednesday
# 10         Wednesday
# 11          Thursday
# 12         Wednesday
# 13            Monday
# 14            Monday
# 15          Thursday
# 16           Tuesday
# 17            Sunday
# 18            Sunday
# 19            Friday
# 20           Tuesday
# 21          Thursday
# 22          Thursday
# 23            Friday
# 24           Tuesday
# 25            Sunday
# 26            Sunday
# 27         Wednesday
# 28            Friday
# 29            Friday
#              ...
# 1123435       Sunday
# 1123436       Sunday
# 1123437       Friday
# 1123438       Sunday
# 1123439       Friday
# 1123440       Sunday
# 1123441       Monday
# 1123442    Wednesday
# 1123443    Wednesday
# 1123444    Wednesday
# 1123445     Thursday
# 1123446     Thursday
# ...

# %%
df.Offense
# Out:
# 0                                BURGLARY
# 1                           GRAND LARCENY
# 2                                BURGLARY
# 3          GRAND LARCENY OF MOTOR VEHICLE
# 4                           GRAND LARCENY
# 5                           GRAND LARCENY
# 6                           GRAND LARCENY
# 7                           GRAND LARCENY
# 8                                    RAPE
# 9                           GRAND LARCENY
# 10                                   RAPE
# 11                          GRAND LARCENY
# 12                          GRAND LARCENY
# 13                          GRAND LARCENY
# 14                          GRAND LARCENY
# 15                          GRAND LARCENY
# 16                          GRAND LARCENY
# 17                                   RAPE
# 18                                ROBBERY
# 19                          GRAND LARCENY
# 20                          GRAND LARCENY
# 21                          GRAND LARCENY
# ...

# %%
df.loc[0]
# Out:
# OBJECTID                                                      1
# Identifier                                             f070032d
# Occurrence Date                          09/06/1940 07:30:00 PM
# Day of Week                                              Friday
# Occurrence Month                                            Sep
# Occurrence Day                                                6
# Occurrence Year                                            1940
# Occurrence Hour                                              19
# CompStat Month                                                9
# CompStat Day                                                  7
# CompStat Year                                              2010
# Offense                                                BURGLARY
# Offense Classification                                   FELONY
# Sector                                                        D
# Precinct                                                     66
# ...

# %%
df.loc[0].Offense
# Out:
# 'BURGLARY'

# %%
df.ix[0, 3]
# Out:
# 'Friday'

# %%
df.at[0, "Offense"]
# Out:
# 'BURGLARY'

# %%
df[df["Day of Week"].isnull()]
# Out:
#          OBJECTID Identifier Occurrence Date Day of Week Occurrence Month  \
# 764443   764444.0   6aa584a1             NaN         NaN              NaN
# 764444   764445.0   8b114108             NaN         NaN              NaN
# 764445   764446.0   7b9267ae             NaN         NaN              NaN
# 764446   764447.0   1f5f1c35             NaN         NaN              NaN
# 764447   764448.0   8307c8d2             NaN         NaN              NaN
# 764448   764449.0   a0d65746             NaN         NaN              NaN
# 764449   764450.0   d5c1e45b             NaN         NaN              NaN
# 764450   764451.0   ca6f64b0             NaN         NaN              NaN
# 764451   764452.0   78a9ebca             NaN         NaN              NaN
# 764452   764453.0   5f354c5a             NaN         NaN              NaN
# 764453   764454.0   3d709916             NaN         NaN              NaN
# 764454   764455.0   1bce8c43             NaN         NaN              NaN
# ...

# %%
df[df["Day of Week"].notnull()]
# Out:
#           OBJECTID Identifier         Occurrence Date Day of Week  \
# 0              1.0   f070032d  09/06/1940 07:30:00 PM      Friday
# 1              2.0   c6245d4d  12/14/1968 12:20:00 AM    Saturday
# 2              3.0   716dbc6f  10/30/1970 03:30:00 PM      Friday
# 3              4.0   638cd7b7  07/18/1972 11:00:00 PM     Tuesday
# 4              5.0   6e410287  05/21/1987 12:01:00 AM    Thursday
# 5              6.0   7eebfe3c  02/01/1990 09:00:00 AM    Thursday
# 6              7.0   da21f94f  11/13/1990 12:01:00 AM     Tuesday
# 7              8.0   87c99e8c  02/02/1992 04:00:00 PM      Sunday
# 8              9.0   495f57e1  08/08/1994 06:00:00 PM      Monday
# 9             10.0   31c0b727  10/26/1994 12:01:00 AM   Wednesday
# 10            11.0   c43b188b  02/01/1995 08:00:00 AM   Wednesday
# 11            12.0   81770cd9  02/01/1996 03:00:00 PM    Thursday
# 12            13.0   cb5b6e80  04/15/1998 09:00:00 AM   Wednesday
# ...

# %%
df[df["Occurrence Year"]==1970]
# Out:
#          OBJECTID Identifier         Occurrence Date Day of Week  \
# 2             3.0   716dbc6f  10/30/1970 03:30:00 PM      Friday
# 1119927    1038.0   da028384  08/06/1970 09:40:00 PM    Thursday
#
#         Occurrence Month  Occurrence Day  Occurrence Year  Occurrence Hour  \
# 2                    Oct            30.0           1970.0             15.0
# 1119927              Aug             6.0           1970.0             21.0
#
#          CompStat Month  CompStat Day  CompStat Year  \
# 2                  10.0          31.0         2008.0
# 1119927             8.0          25.0         2008.0
#
#                                 Offense Offense Classification Sector  \
# 2                              BURGLARY                 FELONY      H
# 1119927  MURDER & NON-NEGL. MANSLAUGHTE                 FELONY      C
#
#          Precinct   Borough      Jurisdiction  XCoordinate  YCoordinate  \
# 2            84.0  BROOKLYN  N.Y. POLICE DEPT     986508.0     190249.0
# ...

# %%
df[(df["Day of Week"]=="Friday") & (df["Offense"]=="BURGLARY")]
# Out:
#           OBJECTID Identifier         Occurrence Date Day of Week  \
# 0              1.0   f070032d  09/06/1940 07:30:00 PM      Friday
# 2              3.0   716dbc6f  10/30/1970 03:30:00 PM      Friday
# 29            30.0   8f4d92fd  11/17/2000 05:20:00 PM      Friday
# 255          256.0   4b1172af  12/09/2005 07:00:00 PM      Friday
# 1608        1609.0   a223042d  03/17/2006 12:01:00 AM      Friday
# 1617        1618.0    4b07cca  03/17/2006 12:45:00 AM      Friday
# 1625        1626.0   3cdbc8c7  03/17/2006 02:10:00 AM      Friday
# 1630        1631.0   836f38f0  03/17/2006 03:05:00 AM      Friday
# 1631        1632.0   cb2fa007  03/17/2006 03:12:00 AM      Friday
# 1632        1633.0    3cf2f77  03/17/2006 03:12:00 AM      Friday
# 1633        1634.0   7cf863d2  03/17/2006 03:30:00 AM      Friday
# 1640        1641.0   7981cbcb  03/17/2006 05:00:00 AM      Friday
# 1646        1647.0   5218540b  03/17/2006 06:00:00 AM      Friday
# ...

# %%
df[["Occurrence Year", "Occurrence Day", "Offense"]]
# Out:
#          Occurrence Year  Occurrence Day                         Offense
# 0                 1940.0             6.0                        BURGLARY
# 1                 1968.0            14.0                   GRAND LARCENY
# 2                 1970.0            30.0                        BURGLARY
# 3                 1972.0            18.0  GRAND LARCENY OF MOTOR VEHICLE
# 4                 1987.0            21.0                   GRAND LARCENY
# 5                 1990.0             1.0                   GRAND LARCENY
# 6                 1990.0            13.0                   GRAND LARCENY
# 7                 1992.0             2.0                   GRAND LARCENY
# 8                 1994.0             8.0                            RAPE
# 9                 1994.0            26.0                   GRAND LARCENY
# 10                1995.0             1.0                            RAPE
# 11                1996.0             1.0                   GRAND LARCENY
# ...

# %%
df[(df["Day of Week"]=="Friday") & (df["Offense"]=="BURGLARY")][["Occurrence Year", "Occurrence Day", "Offense"]]
# Out:
#          Occurrence Year  Occurrence Day   Offense
# 0                 1940.0             6.0  BURGLARY
# 2                 1970.0            30.0  BURGLARY
# 29                2000.0            17.0  BURGLARY
# 255               2005.0             9.0  BURGLARY
# 1608              2006.0            17.0  BURGLARY
# 1617              2006.0            17.0  BURGLARY
# 1625              2006.0            17.0  BURGLARY
# 1630              2006.0            17.0  BURGLARY
# 1631              2006.0            17.0  BURGLARY
# 1632              2006.0            17.0  BURGLARY
# 1633              2006.0            17.0  BURGLARY
# 1640              2006.0            17.0  BURGLARY
# 1646              2006.0            17.0  BURGLARY
# 1647              2006.0            17.0  BURGLARY
# 1648              2006.0            17.0  BURGLARY
# 1649              2006.0            17.0  BURGLARY
# 1651              2006.0            17.0  BURGLARY
# ...

# %%
df.Offense.unique()
# Out:
# array(['BURGLARY', 'GRAND LARCENY', 'GRAND LARCENY OF MOTOR VEHICLE',
#        'RAPE', 'ROBBERY', 'FELONY ASSAULT',
#        'MURDER & NON-NEGL. MANSLAUGHTE', nan], dtype=object)

# %%
df.Offense.value_counts()
# Out:
# GRAND LARCENY                     428993
# ROBBERY                           198744
# BURGLARY                          191369
# FELONY ASSAULT                    184042
# GRAND LARCENY OF MOTOR VEHICLE    101963
# RAPE                               13779
# MURDER & NON-NEGL. MANSLAUGHTE      4574
# Name: Offense, dtype: int64

# %%
sum(df.Offense.value_counts())
# Out:
# 1123464

# %%
len(df)
# Out:
# 1123465

# %%
df.Offense.value_counts(dropna=False)
# Out:
# GRAND LARCENY                     428993
# ROBBERY                           198744
# BURGLARY                          191369
# FELONY ASSAULT                    184042
# GRAND LARCENY OF MOTOR VEHICLE    101963
# RAPE                               13779
# MURDER & NON-NEGL. MANSLAUGHTE      4574
# NaN                                    1
# Name: Offense, dtype: int64

# %%
df.head(5)
# Out:
#    OBJECTID Identifier         Occurrence Date Day of Week Occurrence Month  \
# 0       1.0   f070032d  09/06/1940 07:30:00 PM      Friday              Sep
# 1       2.0   c6245d4d  12/14/1968 12:20:00 AM    Saturday              Dec
# 2       3.0   716dbc6f  10/30/1970 03:30:00 PM      Friday              Oct
# 3       4.0   638cd7b7  07/18/1972 11:00:00 PM     Tuesday              Jul
# 4       5.0   6e410287  05/21/1987 12:01:00 AM    Thursday              May
#
#    Occurrence Day  Occurrence Year  Occurrence Hour  CompStat Month  \
# 0             6.0           1940.0             19.0             9.0
# 1            14.0           1968.0              0.0            12.0
# 2            30.0           1970.0             15.0            10.0
# 3            18.0           1972.0             23.0             7.0
# 4            21.0           1987.0              0.0             5.0
#
#    CompStat Day  CompStat Year                         Offense  \
# ...

# %%
df.columns
# Out:
# Index(['OBJECTID', 'Identifier', 'Occurrence Date', 'Day of Week',
#        'Occurrence Month', 'Occurrence Day', 'Occurrence Year',
#        'Occurrence Hour', 'CompStat Month', 'CompStat Day', 'CompStat Year',
#        'Offense', 'Offense Classification', 'Sector', 'Precinct', 'Borough',
#        'Jurisdiction', 'XCoordinate', 'YCoordinate', 'Location 1'],
#       dtype='object')

# %%
df.rename(columns={"Occurrence Year": "OccurrenceYear", "DayOfWeek": "Day_Of_Week"}, inplace=True)

# %%
df.head(5)
# Out:
#    OBJECTID Identifier         Occurrence Date Day_Of_Week Occurrence Month  \
# 0       1.0   f070032d  09/06/1940 07:30:00 PM      Friday              Sep
# 1       2.0   c6245d4d  12/14/1968 12:20:00 AM    Saturday              Dec
# 2       3.0   716dbc6f  10/30/1970 03:30:00 PM      Friday              Oct
# 3       4.0   638cd7b7  07/18/1972 11:00:00 PM     Tuesday              Jul
# 4       5.0   6e410287  05/21/1987 12:01:00 AM    Thursday              May
#
#    Occurrence Day  OccurrenceYear  Occurrence Hour  CompStat Month  \
# 0             6.0          1940.0             19.0             9.0
# 1            14.0          1968.0              0.0            12.0
# 2            30.0          1970.0             15.0            10.0
# 3            18.0          1972.0             23.0             7.0
# 4            21.0          1987.0              0.0             5.0
#
#    CompStat Day  CompStat Year                         Offense  \
# ...

# %%
df.columns
# Out:
# Index(['OBJECTID', 'Identifier', 'Occurrence Date', 'Day of Week',
#        'Occurrence Month', 'Occurrence Day', 'OccurrenceYear',
#        'Occurrence Hour', 'CompStat Month', 'CompStat Day', 'CompStat Year',
#        'Offense', 'Offense Classification', 'Sector', 'Precinct', 'Borough',
#        'Jurisdiction', 'XCoordinate', 'YCoordinate', 'Location 1'],
#       dtype='object')

# %%
df["CompStat Day"].mode()
# Out:
# 0    20.0
# dtype: float64

# %%
s = pd.Series([1,1,2,2,2,2,3,4])

# %%
s
# Out:
# 0    1
# 1    1
# 2    2
# 3    2
# 4    2
# 5    2
# 6    3
# 7    4
# dtype: int64

# %%
s.mod()
# Out:
# ------------------------------------------------------------------------
# TypeError                              Traceback (most recent call last)
# <ipython-input-62-6b15aae6c2e4> in <module>()
# ----> 1 s.mod()
#
# TypeError: flex_wrapper() missing 1 required positional argument: 'other'

# %%
pd.mod(s)
# Out:
# ------------------------------------------------------------------------
# AttributeError                         Traceback (most recent call last)
# <ipython-input-63-74d5012c592d> in <module>()
# ----> 1 pd.mod(s)
#
# AttributeError: module 'pandas' has no attribute 'mod'

# %%
(s.mean(), s.max(), s.min(), s.median(), s.mode())
# Out:
# (2.125, 4, 1, 2.0, 0    2
#  dtype: int64)

# %%
df["CompStat Day"].describe()
# Out:
# count    1.123463e+06
# mean     1.579072e+01
# std      8.796314e+00
# min      1.000000e+00
# 25%      8.000000e+00
# 50%      1.600000e+01
# 75%      2.300000e+01
# max      3.100000e+01
# Name: CompStat Day, dtype: float64

# %%
df.dtypes
# Out:
# OBJECTID                  float64
# Identifier                 object
# Occurrence Date            object
# Day_Of_Week                object
# Occurrence Month           object
# Occurrence Day            float64
# OccurrenceYear            float64
# Occurrence Hour           float64
# CompStat Month            float64
# CompStat Day              float64
# CompStat Year             float64
# Offense                    object
# Offense Classification     object
# Sector                     object
# Precinct                  float64
# Borough                    object
# Jurisdiction               object
# XCoordinate               float64
# YCoordinate               float64
# Location 1                 object
# dtype: object

# %%
df["Location 1"].head(5)
# Out:
# 0    (40.6227027620001, -73.9883732929999)
# 1        (40.8037530600001, -73.955861904)
# 2        (40.688874254, -73.9918594329999)
# 3    (40.6674141890001, -73.9220463899999)
# 4        (40.6668988440001, -73.878495425)
# Name: Location 1, dtype: object

# %%
df["YYYYMMDD"] = df["OccurrenceYear"]*10

# %%
df.head()
# Out:
#    OBJECTID Identifier         Occurrence Date Day_Of_Week Occurrence Month  \
# 0       1.0   f070032d  09/06/1940 07:30:00 PM      Friday              Sep
# 1       2.0   c6245d4d  12/14/1968 12:20:00 AM    Saturday              Dec
# 2       3.0   716dbc6f  10/30/1970 03:30:00 PM      Friday              Oct
# 3       4.0   638cd7b7  07/18/1972 11:00:00 PM     Tuesday              Jul
# 4       5.0   6e410287  05/21/1987 12:01:00 AM    Thursday              May
#
#    Occurrence Day  OccurrenceYear  Occurrence Hour  CompStat Month  \
# 0             6.0          1940.0             19.0             9.0
# 1            14.0          1968.0              0.0            12.0
# 2            30.0          1970.0             15.0            10.0
# 3            18.0          1972.0             23.0             7.0
# 4            21.0          1987.0              0.0             5.0
#
#    CompStat Day   ...                            Offense  \
# ...

# %%
s = "(40.6227027620001, -73.9883732929999)"
float(s[1:s.index(",")])
# Out:
# 40.6227027620001

# %%
float(s[s.index(",")+1:-1])
# Out:
# -73.9883732929999

# %%
def parseLocation(loc):
    return (float(loc[1:loc.index(",")]), float(loc[loc.index(",")+1:-1]))

# %%
parseLocation("(40.6227027620001, -73.9883732929999)")
# Out:
# (40.6227027620001, -73.9883732929999)

# %%
help(df.apply)
# Out:
# Help on method apply in module pandas.core.frame:
#
# apply(func, axis=0, broadcast=False, raw=False, reduce=None, args=(), **kwds) method of pandas.core.frame.DataFrame instance
#     Applies function along input axis of DataFrame.
#
#     Objects passed to functions are Series objects having index
#     either the DataFrame's index (axis=0) or the columns (axis=1).
#     Return type depends on whether passed function aggregates, or the
#     reduce argument if the DataFrame is empty.
#
#     Parameters
#     ----------
#     func : function
#         Function to apply to each column/row
#     axis : {0 or 'index', 1 or 'columns'}, default 0
#         * 0 or 'index': apply function to each column
#         * 1 or 'columns': apply function to each row
#     broadcast : boolean, default False
#         For aggregation functions, return object of same size with values
#         propagated
#     raw : boolean, default False
# ...

# %%
clean_df["loc"] = clean_df.apply(lambda row: parseLocation(row["Location 1"]), axis=1)

# %%
clean_df.head(5)
# Out:
#      OBJECTID Identifier         Occurrence Date Day_Of_Week Occurrence Month  \
# 257     258.0   13b6949b  01/09/2006 12:00:00 AM      Monday              Jan
# 258     259.0   c9cc0e6d  01/09/2006 12:00:00 AM      Monday              Jan
# 259     260.0   b6c31b82  01/09/2006 12:00:00 AM      Monday              Jan
# 260     261.0   2598f1c7  01/09/2006 12:00:00 AM      Monday              Jan
# 261     262.0   5b4df445  01/09/2006 12:00:00 AM      Monday              Jan
#
#      Occurrence Day  OccurrenceYear  Occurrence Hour  CompStat Month  \
# 257             9.0          2006.0              0.0             8.0
# 258             9.0          2006.0              0.0             1.0
# 259             9.0          2006.0              0.0             2.0
# 260             9.0          2006.0              0.0             1.0
# 261             9.0          2006.0              0.0             1.0
#
#      CompStat Day                  ...                    \
# ...

# %%
clean_df["loc"].min()
# Out:
# (40.112709974, -77.519206334)

# %%
clean_df["loc"].max()
# Out:
# (59.5805088160001, -73.8954321749999)

# %%
df["loc"].max()
# Out:
# (40.6227027620001, -73.9883732929999)

# %%
df.Offense.value_counts(dropna=False)
# Out:
# GRAND LARCENY                     428993
# ROBBERY                           198744
# BURGLARY                          191369
# FELONY ASSAULT                    184042
# GRAND LARCENY OF MOTOR VEHICLE    101963
# RAPE                               13779
# MURDER & NON-NEGL. MANSLAUGHTE      4574
# NaN                                    1
# Name: Offense, dtype: int64

# %%
df.OccurrenceYear.value_counts(dropna=False)
# Out:
#  2006.0    127887
#  2007.0    120554
#  2008.0    117375
#  2012.0    111798
#  2013.0    111286
#  2011.0    107206
#  2014.0    106849
#  2009.0    106018
#  2010.0    105643
#  2015.0    102657
#  2005.0      3272
#  2004.0       692
#  2003.0       490
#  2002.0       368
#  2001.0       343
#  2000.0       282
# NaN           244
#  1999.0       124
#  1998.0        74
#  1997.0        40
#  1996.0        34
#  1995.0        27
#  1993.0        23
#  1994.0        19
#  1990.0        17
#  1991.0        12
#  1989.0        12
#  1992.0        12
#  1985.0         8
#  1966.0         7
#             ...
#  1910.0         3
#  1914.0         2
#  1945.0         2
#  1965.0         2
#  1970.0         2
#  1905.0         2
#  1975.0         2
#  1972.0         2
#  1986.0         2
#  1978.0         2
#  1976.0         2
#  1969.0         1
#  1908.0         1
#  1911.0         1
#  1912.0         1
#  1983.0         1
#  1920.0         1
#  1940.0         1
#  1946.0         1
# ...

# %%
clean_df = df[(df["OccurrenceYear"]>2005) & df["Offense"].notnull() & df["OccurrenceYear"].notnull()].copy()

# %%
len(clean_df)
# Out:
# 1117273

# %%
len(df)
# Out:
# 1123465

# %%
clean_df.count()
# Out:
# OBJECTID                  1117273
# Identifier                1117273
# Occurrence Date           1117273
# Day_Of_Week               1117273
# Occurrence Month          1117273
# Occurrence Day            1117273
# OccurrenceYear            1117273
# Occurrence Hour           1117273
# CompStat Month            1117273
# CompStat Day              1117273
# CompStat Year             1117273
# Offense                   1117273
# Offense Classification    1117273
# Sector                    1092094
# Precinct                  1117256
# Borough                   1117199
# Jurisdiction              1117273
# XCoordinate               1117273
# YCoordinate               1117273
# Location 1                1117273
# YYYYMMDD                  1117273
# loc                       1117273
# dtype: int64

# %%
df.count()
# Out:
# OBJECTID                  1123464
# Identifier                1123465
# Occurrence Date           1123222
# Day_Of_Week               1123291
# Occurrence Month          1123291
# Occurrence Day            1123291
# OccurrenceYear            1123221
# Occurrence Hour           1123222
# CompStat Month            1123463
# CompStat Day              1123463
# CompStat Year             1123463
# Offense                   1123464
# Offense Classification    1123464
# Sector                    1098137
# Precinct                  1123443
# Borough                   1123384
# Jurisdiction              1123463
# XCoordinate               1123464
# YCoordinate               1123464
# Location 1                1123464
# YYYYMMDD                  1123221
# loc                       1123465
# dtype: int64

# %%
clean_df["Borough"].value_counts()
# Out:
# BROOKLYN         349445
# MANHATTAN        286306
# QUEENS           242506
# BRONX            206501
# STATEN ISLAND     32434
# (null)                7
# Name: Borough, dtype: int64
